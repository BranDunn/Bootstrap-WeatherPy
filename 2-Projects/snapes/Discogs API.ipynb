# %%
import pandas as pd
import requests
import discogs_client

api_key = 'MEfMKxvFBtpPlpGyqgxMojEcgaLHWnfuazRHdWPv'

# %%
d = discogs_client.Client('BranDunn', consumer_key=None, consumer_secret=None, token=None, secret=None, user_token=api_key)

# %%
results = d.search('Stockholm By Night', type='release')
print(results)

# %%
album1 = results[0]

# %%
album1.title
# Out:
# 'The Persuader - Stockholm By Night'

# %%
def datagetter(album_name, client=d):
    #query discogs api
    # unpack
    try:
        return pd.Series([album_name, album1.release,3,5])
    except:
        return pd.Series(['nan','na','na','na'])

# %%
df = pd.DataFrame([['Stockholm By Night', 1],
                  ['Thriller',2]], columns=['album', 'other'])

# %%
album_info = df.album.apply(datagetter )

# %%
pd.merge(df, album_info, left_on=['album'], right_on=[0])
# Out:
# Empty DataFrame
# Columns: [album, other, 0, 1, 2, 3]
# Index: []
